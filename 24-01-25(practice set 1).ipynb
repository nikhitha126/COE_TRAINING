# %%
import pandas as pd
import numpy as np
data=pd.read_csv("Food_Time_Data_Set.csv")

# %%
data
# Out:
#          ID Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings  \
# 0      4607     INDORES13DEL02                 37.0                      4.9
# 1      B379     BANGRES18DEL02                 34.0                      4.5
# 2      5D6D     BANGRES19DEL01                 23.0                      4.4
# 3      7A6A    COIMBRES13DEL02                 38.0                      4.7
# 4      70A2     CHENRES12DEL01                 32.0                      4.6
# ...     ...                ...                  ...                      ...
# 9996   11B4      VADRES13DEL03                 32.0                      4.2
# 9997   8336      HYDRES20DEL01                 36.0                      4.7
# 9998   338B      JAPRES18DEL03                 37.0                      4.6
# 9999   3FB2      MUMRES11DEL03                 29.0                      4.7
# 10000   NaN                NaN                  NaN                      NaN
#
# ...

# %%
data.tail() # to get last 5
# Out:
#          ID Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings  \
# 9996   11B4      VADRES13DEL03                 32.0                      4.2
# 9997   8336      HYDRES20DEL01                 36.0                      4.7
# 9998   338B      JAPRES18DEL03                 37.0                      4.6
# 9999   3FB2      MUMRES11DEL03                 29.0                      4.7
# 10000   NaN                NaN                  NaN                      NaN
#
#        Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude  \
# 9996             22.310237             73.158921                   22.400237
# 9997             17.483216             78.552111                   17.493216
# 9998             26.913987             75.752891                   27.053987
# 9999             18.994237             72.825553                   19.084237
# 10000                  NaN                   NaN                         NaN
#
# ...

# %%
data.head() # to get first 5
# Out:
#      ID Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings  \
# 0  4607     INDORES13DEL02                 37.0                      4.9
# 1  B379     BANGRES18DEL02                 34.0                      4.5
# 2  5D6D     BANGRES19DEL01                 23.0                      4.4
# 3  7A6A    COIMBRES13DEL02                 38.0                      4.7
# 4  70A2     CHENRES12DEL01                 32.0                      4.6
#
#    Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude  \
# 0            22.745049             75.892471                   22.765049
# 1            12.913041             77.683237                   13.043041
# 2            12.914264             77.678400                   12.924264
# 3            11.003669             76.976494                   11.053669
# 4            12.972793             80.249982                   13.012793
#
#    Delivery_location_longitude Type_of_order Type_of_vehicle  temperature  \
# ...

# %%
data.info()#to get the information about the dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10001 entries, 0 to 10000
# Data columns (total 18 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   ID                           10000 non-null  object
#  1   Delivery_person_ID           10000 non-null  object
#  2   Delivery_person_Age          10000 non-null  float64
#  3   Delivery_person_Ratings      10000 non-null  float64
#  4   Restaurant_latitude          10000 non-null  float64
#  5   Restaurant_longitude         10000 non-null  float64
#  6   Delivery_location_latitude   10000 non-null  float64
#  7   Delivery_location_longitude  10000 non-null  float64
#  8   Type_of_order                10000 non-null  object
#  9   Type_of_vehicle              10000 non-null  object
#  10  temperature                  9995 non-null   float64
#  11  humidity                     9995 non-null   float64
# ...

# %%
data.shape #to know the no.of columns and rows
# Out:
# (10001, 18)

# %%
data.columns # to get all the columns
# Out:
# Index(['ID', 'Delivery_person_ID', 'Delivery_person_Age',
#        'Delivery_person_Ratings', 'Restaurant_latitude',
#        'Restaurant_longitude', 'Delivery_location_latitude',
#        'Delivery_location_longitude', 'Type_of_order', 'Type_of_vehicle',
#        'temperature', 'humidity', 'precipitation', 'weather_description',
#        'Unnamed: 14', 'Traffic_Level', 'Distance (km)', 'TARGET'],
#       dtype='object')

# %%
data.iloc[10:20,1:3]
# Out:
#    Delivery_person_ID  Delivery_person_Age
# 10      KOCRES16DEL01                 21.0
# 11     PUNERES13DEL03                 23.0
# 12     LUDHRES15DEL02                 34.0
# 13      KNPRES14DEL02                 24.0
# 14      MUMRES15DEL03                 29.0
# 15      MYSRES01DEL01                 35.0
# 16     PUNERES20DEL01                 33.0
# 17      HYDRES14DEL01                 34.0
# 18      KOLRES15DEL03                 21.0
# 19     PUNERES19DEL02                 25.0

# %%
data.isnull() #to know is there any null values in the dataset
# Out:
#           ID  Delivery_person_ID  Delivery_person_Age  \
# 0      False               False                False
# 1      False               False                False
# 2      False               False                False
# 3      False               False                False
# 4      False               False                False
# ...      ...                 ...                  ...
# 9996   False               False                False
# 9997   False               False                False
# 9998   False               False                False
# 9999   False               False                False
# 10000   True                True                 True
#
#        Delivery_person_Ratings  Restaurant_latitude  Restaurant_longitude  \
# 0                        False                False                 False
# 1                        False                False                 False
# 2                        False                False                 False
# ...

# %%
data.isnull().sum() #to get the count of null values in each column
# Out:
# ID                                 1
# Delivery_person_ID                 1
# Delivery_person_Age                1
# Delivery_person_Ratings            1
# Restaurant_latitude                1
# Restaurant_longitude               1
# Delivery_location_latitude         1
# Delivery_location_longitude        1
# Type_of_order                      1
# Type_of_vehicle                    1
# temperature                        6
# humidity                           6
# precipitation                      6
# weather_description                6
# Unnamed: 14                    10001
# Traffic_Level                    916
# Distance (km)                    921
# TARGET                           542
# dtype: int64

# %%
data['temperature'] #to get a particular column
# Out:
# 0        17.11
# 1        19.50
# 2        20.45
# 3        23.86
# 4        26.55
#          ...
# 9996     23.96
# 9997     22.94
# 9998     23.72
# 9999     28.01
# 10000      NaN
# Name: temperature, Length: 10001, dtype: float64

# %%
data['Delivery_person_ID'].unique() #to get the unique values
# Out:
# array(['INDORES13DEL02', 'BANGRES18DEL02', 'BANGRES19DEL01', ...,
#        'BHPRES09DEL02', 'ALHRES13DEL01', nan], dtype=object)

# %%
data.drop_duplicates() # to remove the duplicates
# Out:
#          ID Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings  \
# 0      4607     INDORES13DEL02                 37.0                      4.9
# 1      B379     BANGRES18DEL02                 34.0                      4.5
# 2      5D6D     BANGRES19DEL01                 23.0                      4.4
# 3      7A6A    COIMBRES13DEL02                 38.0                      4.7
# 4      70A2     CHENRES12DEL01                 32.0                      4.6
# ...     ...                ...                  ...                      ...
# 9996   11B4      VADRES13DEL03                 32.0                      4.2
# 9997   8336      HYDRES20DEL01                 36.0                      4.7
# 9998   338B      JAPRES18DEL03                 37.0                      4.6
# 9999   3FB2      MUMRES11DEL03                 29.0                      4.7
# 10000   NaN                NaN                  NaN                      NaN
#
# ...

# %%
data.describe()
# Out:
#        Delivery_person_Age  Delivery_person_Ratings  Restaurant_latitude  \
# count         10000.000000             10000.000000         10000.000000
# mean             29.522000                 4.629370            16.893418
# std               5.700348                 0.322941             8.330948
# min              15.000000                 1.000000           -30.902872
# 25%              25.000000                 4.500000            12.913041
# 50%              29.000000                 4.700000            18.546258
# 75%              34.000000                 4.800000            22.727021
# max              50.000000                 6.000000            30.914057
#
#        Restaurant_longitude  Delivery_location_latitude  \
# count          10000.000000                10000.000000
# mean              70.177749                   17.412655
# std               23.203352                    7.336846
# min              -88.352885                    0.010000
# ...

# %%
data.rename(columns={'Delivery_person_Age':'Age'},inplace=True)
print(data)
# Out:
#          ID Delivery_person_ID   Age  Delivery_person_Ratings  \
# 0      4607     INDORES13DEL02  37.0                      4.9
# 1      B379     BANGRES18DEL02  34.0                      4.5
# 2      5D6D     BANGRES19DEL01  23.0                      4.4
# 3      7A6A    COIMBRES13DEL02  38.0                      4.7
# 4      70A2     CHENRES12DEL01  32.0                      4.6
# ...     ...                ...   ...                      ...
# 9996   11B4      VADRES13DEL03  32.0                      4.2
# 9997   8336      HYDRES20DEL01  36.0                      4.7
# 9998   338B      JAPRES18DEL03  37.0                      4.6
# 9999   3FB2      MUMRES11DEL03  29.0                      4.7
# 10000   NaN                NaN   NaN                      NaN
#
#        Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude  \
# 0                22.745049             75.892471                   22.765049
# ...

# %%
data['Age'].mean()
# Out:
# 29.522

# %%
data['Age'].median()
# Out:
# 29.0

# %%
data['Age'].mode()
# Out:
# 0    29.0
# Name: Age, dtype: float64

# %%
data['Age'].std()
# Out:
# 5.700347831188897

# %%
correlation=data['Age'].corr(data['Delivery_person_Ratings'])
print(correlation)
# Out:
# -0.07999773190849163

# %%
data.dropna()
# Out:
# Empty DataFrame
# Columns: [ID, Delivery_person_ID, Age, Delivery_person_Ratings, Restaurant_latitude, Restaurant_longitude, Delivery_location_latitude, Delivery_location_longitude, Type_of_order, Type_of_vehicle, temperature, humidity, precipitation, weather_description, Unnamed: 14, Traffic_Level, Distance (km), TARGET]
# Index: []

# %%
print(data.dtypes)
# Out:
# ID                              object
# Delivery_person_ID              object
# Age                            float64
# Delivery_person_Ratings        float64
# Restaurant_latitude            float64
# Restaurant_longitude           float64
# Delivery_location_latitude     float64
# Delivery_location_longitude    float64
# Type_of_order                   object
# Type_of_vehicle                 object
# temperature                    float64
# humidity                       float64
# precipitation                  float64
# weather_description             object
# Unnamed: 14                    float64
# Traffic_Level                   object
# Distance (km)                  float64
# TARGET                          object
# dtype: object

# %%
data.index
# Out:
# RangeIndex(start=0, stop=10001, step=1)

# %%
data.to_numpy
# Out:
# <bound method DataFrame.to_numpy of          ID Delivery_person_ID   Age  Delivery_person_Ratings  \
# 0      4607     INDORES13DEL02  37.0                      4.9
# 1      B379     BANGRES18DEL02  34.0                      4.5
# 2      5D6D     BANGRES19DEL01  23.0                      4.4
# 3      7A6A    COIMBRES13DEL02  38.0                      4.7
# 4      70A2     CHENRES12DEL01  32.0                      4.6
# ...     ...                ...   ...                      ...
# 9996   11B4      VADRES13DEL03  32.0                      4.2
# 9997   8336      HYDRES20DEL01  36.0                      4.7
# 9998   338B      JAPRES18DEL03  37.0                      4.6
# 9999   3FB2      MUMRES11DEL03  29.0                      4.7
# 10000   NaN                NaN   NaN                      NaN
#
#        Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude  \
# 0                22.745049             75.892471                   22.765049
# ...

# %%
data.T
# Out:
#                                       0               1               2      \
# ID                                     4607            B379            5D6D
# Delivery_person_ID           INDORES13DEL02  BANGRES18DEL02  BANGRES19DEL01
# Age                                    37.0            34.0            23.0
# Delivery_person_Ratings                 4.9             4.5             4.4
# Restaurant_latitude               22.745049       12.913041       12.914264
# Restaurant_longitude              75.892471       77.683237         77.6784
# Delivery_location_latitude        22.765049       13.043041       12.924264
# Delivery_location_longitude       75.912471       77.813237         77.6884
# Type_of_order                        Snack           Snack          Drinks
# Type_of_vehicle                 motorcycle         scooter      motorcycle
# temperature                           17.11            19.5           20.45
# ...

# %%
data.fillna(value=5)
# Out:
#          ID Delivery_person_ID   Age  Delivery_person_Ratings  \
# 0      4607     INDORES13DEL02  37.0                      4.9
# 1      B379     BANGRES18DEL02  34.0                      4.5
# 2      5D6D     BANGRES19DEL01  23.0                      4.4
# 3      7A6A    COIMBRES13DEL02  38.0                      4.7
# 4      70A2     CHENRES12DEL01  32.0                      4.6
# ...     ...                ...   ...                      ...
# 9996   11B4      VADRES13DEL03  32.0                      4.2
# 9997   8336      HYDRES20DEL01  36.0                      4.7
# 9998   338B      JAPRES18DEL03  37.0                      4.6
# 9999   3FB2      MUMRES11DEL03  29.0                      4.7
# 10000     5                  5   5.0                      5.0
#
#        Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude  \
# 0                22.745049             75.892471                   22.765049
# ...

# %%
data.isna()
# Out:
#           ID  Delivery_person_ID    Age  Delivery_person_Ratings  \
# 0      False               False  False                    False
# 1      False               False  False                    False
# 2      False               False  False                    False
# 3      False               False  False                    False
# 4      False               False  False                    False
# ...      ...                 ...    ...                      ...
# 9996   False               False  False                    False
# 9997   False               False  False                    False
# 9998   False               False  False                    False
# 9999   False               False  False                    False
# 10000   True                True   True                     True
#
#        Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude  \
# 0                    False                 False                       False
# ...
